# %% [markdown]
# ## Q 1-3

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split

data = load_wine()
x = data.data
y = data.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=1)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
  'criterion': ['entropy', 'gini'],
  'splitter': ['random', 'best'],
  'min_samples_split': [2, 4, 6, 8, 10],
  'max_depth': [3, 4, 5, 6]
}
cv = GridSearchCV(param_grid=param_grid, estimator=dt, cv=4)

# %%
cv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(random_state=1),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [3, 4, 5, 6],
#                          'min_samples_split': [2, 4, 6, 8, 10],
#                          'splitter': ['random', 'best']})

# %%
cv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 3,
#  'min_samples_split': 2,
#  'splitter': 'best'}

# %%
best_dt = cv.best_estimator_
best_dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=1)

# %%
best_dt.score(x_test, y_test)
# Out:
# 0.9259259259259259

# %% [markdown]
# # Q 4-7

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

data = load_diabetes()
x = data.data
y = data.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor(random_state=1, criterion='squared_error', splitter='random', max_leaf_nodes=10)

# %%
dtr.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=10, random_state=1, splitter='random')

# %%
dtr.score(x_train, y_train)
# Out:
# 0.5032060624566737

# %%
dtr.score(x_test, y_test)
# Out:
# 0.218771375137222

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 10))
plot_tree(dtr, filled=True, feature_names=data.feature_names)
plt.show()

# %% [markdown]
# # Q 8-10

# %%
dtr = DecisionTreeRegressor(max_depth=4, random_state=1)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
  'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
  'splitter': ['random', 'best'],
  'max_features': [4, 5, 6, 'sqrt', 'log2'],
  'ccp_alpha': [0.001, 0.01, 0.02, 0.05]
}
cv = GridSearchCV(param_grid=param_grid, estimator=dtr, cv=4)

# %%
cv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeRegressor(max_depth=4, random_state=1),
#              param_grid={'ccp_alpha': [0.001, 0.01, 0.02, 0.05],
#                          'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [4, 5, 6, 'sqrt', 'log2'],
#                          'splitter': ['random', 'best']})

# %%
cv.score(x_test, y_test)
# Out:
# 0.2276927113007854

# %%
cv.best_params_
# Out:
# {'ccp_alpha': 0.001,
#  'criterion': 'squared_error',
#  'max_features': 5,
#  'splitter': 'random'}
